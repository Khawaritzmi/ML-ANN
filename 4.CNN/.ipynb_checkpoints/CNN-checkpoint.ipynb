# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, AveragePooling2D
from keras.utils import np_utils

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('C:\\Users\\aftermath\\Documents\\CS-101\\JARINGAN SARAF TIRUAN\\tugas1\\4.CNN\\training_set',target_size=(64,64),batch_size=32,class_mode='binary')
testing_set = test_datagen.flow_from_directory('C:\\Users\\aftermath\\Documents\\CS-101\\JARINGAN SARAF TIRUAN\\tugas1\\4.CNN\\testing_set',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# Found 389 images belonging to 2 classes.
# Found 97 images belonging to 2 classes.

# %% [markdown]
# ## Max Pool

# %%
max = Sequential()
#Convolve-Pool
max.add(Conv2D(filters=32,kernel_size=(3,3), input_shape = (64,64,3), activation = 'relu'))
max.add(MaxPooling2D(pool_size = (2,2)))

#Flatten
max.add(Flatten())
#Fully-connected
max.add(Dense(units=128, activation = 'relu'))
max.add(Dense(units=1, activation = 'sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
max.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
maxhistory = max.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# WARNING:tensorflow:From C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# C:\Users\aftermath\Anaconda3\lib\site-packages\PIL\Image.py:969: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# 40/40 [==============================] - 104s 3s/step - loss: 0.7678 - acc: 0.6744 - val_loss: 0.4372 - val_acc: 0.7713
# Epoch 2/20
# 40/40 [==============================] - 39s 982ms/step - loss: 0.3187 - acc: 0.8734 - val_loss: 0.3079 - val_acc: 0.8855
# Epoch 3/20
# 40/40 [==============================] - 39s 966ms/step - loss: 0.2602 - acc: 0.8996 - val_loss: 0.4200 - val_acc: 0.8527
# Epoch 4/20
# 40/40 [==============================] - 39s 982ms/step - loss: 0.2399 - acc: 0.9080 - val_loss: 0.3375 - val_acc: 0.9031
# Epoch 5/20
# 40/40 [==============================] - 39s 971ms/step - loss: 0.1827 - acc: 0.9333 - val_loss: 0.3248 - val_acc: 0.8992
# Epoch 6/20
# 40/40 [==============================] - 38s 946ms/step - loss: 0.1704 - acc: 0.9356 - val_loss: 0.3633 - val_acc: 0.9031
# Epoch 7/20
# 40/40 [==============================] - 40s 990ms/step - loss: 0.1493 - acc: 0.9466 - val_loss: 0.3359 - val_acc: 0.8992
# Epoch 8/20
# 40/40 [==============================] - 38s 959ms/step - loss: 0.1129 - acc: 0.9646 - val_loss: 0.5109 - val_acc: 0.8414
# Epoch 9/20
# 40/40 [==============================] - 38s 957ms/step - loss: 0.1295 - acc: 0.9568 - val_loss: 0.3920 - val_acc: 0.8876
# Epoch 10/20
# 40/40 [==============================] - 39s 987ms/step - loss: 0.0938 - acc: 0.9677 - val_loss: 0.4033 - val_acc: 0.8987
# Epoch 11/20
# 40/40 [==============================] - 39s 973ms/step - loss: 0.0878 - acc: 0.9695 - val_loss: 0.4170 - val_acc: 0.8837
# Epoch 12/20
# 40/40 [==============================] - 38s 958ms/step - loss: 0.0796 - acc: 0.9742 - val_loss: 0.3485 - val_acc: 0.9031
# Epoch 13/20
# 40/40 [==============================] - 37s 935ms/step - loss: 0.0797 - acc: 0.9749 - val_loss: 0.3689 - val_acc: 0.9070
# Epoch 14/20
# 40/40 [==============================] - 38s 961ms/step - loss: 0.0853 - acc: 0.9726 - val_loss: 0.5020 - val_acc: 0.8722
# Epoch 15/20
# 40/40 [==============================] - 39s 985ms/step - loss: 0.0606 - acc: 0.9812 - val_loss: 0.4172 - val_acc: 0.9070
# Epoch 16/20
# 40/40 [==============================] - 39s 968ms/step - loss: 0.0519 - acc: 0.9875 - val_loss: 0.4399 - val_acc: 0.8855
# Epoch 17/20
# 40/40 [==============================] - 39s 963ms/step - loss: 0.0438 - acc: 0.9875 - val_loss: 0.4705 - val_acc: 0.8915
# Epoch 18/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.0373 - acc: 0.9906 - val_loss: 0.4653 - val_acc: 0.8899
# Epoch 19/20
# 40/40 [==============================] - 38s 948ms/step - loss: 0.0364 - acc: 0.9851 - val_loss: 0.5009 - val_acc: 0.8798
# Epoch 20/20
# 40/40 [==============================] - 38s 941ms/step - loss: 0.0485 - acc: 0.9828 - val_loss: 0.6263 - val_acc: 0.8326

# %%
# summarize history for accuracy
plt.plot(maxhistory.history['acc'])
plt.plot(maxhistory.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower left')
plt.ylim(ymin=0)
plt.show()
# summarize history for loss
plt.plot(maxhistory.history['loss'])
plt.plot(maxhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymax=1)
plt.show()

# %%
max1 = Sequential()
#Convolve-Pool
max1.add(Conv2D(filters=32,kernel_size=(3,3), input_shape = (64,64,3), activation = 'relu'))
max1.add(MaxPooling2D(pool_size = (2,2)))

max1.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
max1.add(MaxPooling2D(pool_size=(2,2)))
max1.add(Dropout(0.25))

#Flatten
max1.add(Flatten())
#Fully-connected
max1.add(Dense(units=128, activation = 'relu'))
max1.add(Dense(units=1, activation = 'sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\aftermath\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
max1.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
max1history = max1.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 39s 972ms/step - loss: 0.6419 - acc: 0.7034 - val_loss: 0.4502 - val_acc: 0.7974
# Epoch 2/20
# 40/40 [==============================] - 38s 954ms/step - loss: 0.3251 - acc: 0.8771 - val_loss: 0.3611 - val_acc: 0.8760
# Epoch 3/20
# 40/40 [==============================] - 40s 992ms/step - loss: 0.2836 - acc: 0.8916 - val_loss: 0.5410 - val_acc: 0.8238
# Epoch 4/20
# 40/40 [==============================] - 38s 955ms/step - loss: 0.2808 - acc: 0.8797 - val_loss: 0.4821 - val_acc: 0.8488
# Epoch 5/20
# 40/40 [==============================] - 37s 924ms/step - loss: 0.2355 - acc: 0.9009 - val_loss: 0.5692 - val_acc: 0.8370
# Epoch 6/20
# 40/40 [==============================] - 38s 955ms/step - loss: 0.2118 - acc: 0.9180 - val_loss: 0.5993 - val_acc: 0.8450
# Epoch 7/20
# 40/40 [==============================] - 39s 969ms/step - loss: 0.1907 - acc: 0.9182 - val_loss: 0.6376 - val_acc: 0.8502
# Epoch 8/20
# 40/40 [==============================] - 39s 977ms/step - loss: 0.1913 - acc: 0.9245 - val_loss: 0.3812 - val_acc: 0.8760
# Epoch 9/20
# 40/40 [==============================] - 37s 923ms/step - loss: 0.1283 - acc: 0.9575 - val_loss: 0.4462 - val_acc: 0.9163
# Epoch 10/20
# 40/40 [==============================] - 39s 982ms/step - loss: 0.1126 - acc: 0.9591 - val_loss: 0.6570 - val_acc: 0.8527
# Epoch 11/20
# 40/40 [==============================] - 41s 1s/step - loss: 0.0847 - acc: 0.9671 - val_loss: 0.5688 - val_acc: 0.8678
# Epoch 12/20
# 40/40 [==============================] - 38s 959ms/step - loss: 0.0688 - acc: 0.9765 - val_loss: 0.5970 - val_acc: 0.8721
# Epoch 13/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.0575 - acc: 0.9820 - val_loss: 0.4682 - val_acc: 0.8899
# Epoch 14/20
# 40/40 [==============================] - 39s 983ms/step - loss: 0.0858 - acc: 0.9636 - val_loss: 0.3517 - val_acc: 0.9109
# Epoch 15/20
# 40/40 [==============================] - 38s 960ms/step - loss: 0.1287 - acc: 0.9524 - val_loss: 0.4128 - val_acc: 0.8634
# Epoch 16/20
# 40/40 [==============================] - 39s 969ms/step - loss: 0.0719 - acc: 0.9734 - val_loss: 0.3725 - val_acc: 0.8992
# Epoch 17/20
# 40/40 [==============================] - 39s 963ms/step - loss: 0.0644 - acc: 0.9797 - val_loss: 0.3550 - val_acc: 0.9119
# Epoch 18/20
# 40/40 [==============================] - 38s 946ms/step - loss: 0.0338 - acc: 0.9914 - val_loss: 0.2756 - val_acc: 0.9419
# Epoch 19/20
# 40/40 [==============================] - 39s 975ms/step - loss: 0.0398 - acc: 0.9883 - val_loss: 0.4462 - val_acc: 0.9251
# Epoch 20/20
# 40/40 [==============================] - 39s 970ms/step - loss: 0.0277 - acc: 0.9945 - val_loss: 0.4441 - val_acc: 0.9070

# %%
# summarize history for accuracy
plt.plot(max1history.history['acc'])
plt.plot(max1history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower left')
plt.ylim(ymin=0)
plt.show()
# summarize history for loss
plt.plot(max1history.history['loss'])
plt.plot(max1history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymax=1)
plt.show()

# %% [markdown]
# ## Average Pool

# %%
avg = Sequential()
#Convolve-Pool
avg.add(Conv2D(32,(3,3), input_shape = (64,64,3), activation = 'relu'))
avg.add(AveragePooling2D(pool_size=(2, 2)))

#Flatten
avg.add(Flatten())
#Fully-connected
avg.add(Dense(units=128, activation = 'relu'))
avg.add(Dense(units=1, activation = 'sigmoid'))

# %%
avg.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
avghistory = avg.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 40s 989ms/step - loss: 0.5382 - acc: 0.7742 - val_loss: 0.3423 - val_acc: 0.8488
# Epoch 2/20
# 40/40 [==============================] - 39s 968ms/step - loss: 0.3421 - acc: 0.8597 - val_loss: 0.3038 - val_acc: 0.9075
# Epoch 3/20
# 40/40 [==============================] - 39s 973ms/step - loss: 0.2148 - acc: 0.9168 - val_loss: 0.3189 - val_acc: 0.8721
# Epoch 4/20
# 40/40 [==============================] - 39s 964ms/step - loss: 0.1914 - acc: 0.9288 - val_loss: 0.3275 - val_acc: 0.8811
# Epoch 5/20
# 40/40 [==============================] - 38s 955ms/step - loss: 0.2003 - acc: 0.9253 - val_loss: 0.3113 - val_acc: 0.8953
# Epoch 6/20
# 40/40 [==============================] - 39s 979ms/step - loss: 0.1467 - acc: 0.9403 - val_loss: 0.3380 - val_acc: 0.8502
# Epoch 7/20
# 40/40 [==============================] - 39s 976ms/step - loss: 0.1299 - acc: 0.9487 - val_loss: 0.3411 - val_acc: 0.8837
# Epoch 8/20
# 40/40 [==============================] - 38s 955ms/step - loss: 0.1542 - acc: 0.9364 - val_loss: 0.3421 - val_acc: 0.8855
# Epoch 9/20
# 40/40 [==============================] - 39s 963ms/step - loss: 0.0995 - acc: 0.9710 - val_loss: 0.3080 - val_acc: 0.8721
# Epoch 10/20
# 40/40 [==============================] - 38s 951ms/step - loss: 0.1060 - acc: 0.9583 - val_loss: 0.4023 - val_acc: 0.8546
# Epoch 11/20
# 40/40 [==============================] - 39s 971ms/step - loss: 0.0905 - acc: 0.9724 - val_loss: 0.3112 - val_acc: 0.9147
# Epoch 12/20
# 40/40 [==============================] - 39s 968ms/step - loss: 0.0794 - acc: 0.9765 - val_loss: 0.3337 - val_acc: 0.9119
# Epoch 13/20
# 40/40 [==============================] - 38s 962ms/step - loss: 0.0530 - acc: 0.9883 - val_loss: 0.3742 - val_acc: 0.8837
# Epoch 14/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.0727 - acc: 0.9771 - val_loss: 0.3805 - val_acc: 0.8678
# Epoch 15/20
# 40/40 [==============================] - 38s 952ms/step - loss: 0.0904 - acc: 0.9710 - val_loss: 0.3535 - val_acc: 0.8450
# Epoch 16/20
# 40/40 [==============================] - 39s 978ms/step - loss: 0.1033 - acc: 0.9595 - val_loss: 0.3975 - val_acc: 0.8767
# Epoch 17/20
# 40/40 [==============================] - 38s 961ms/step - loss: 0.0881 - acc: 0.9750 - val_loss: 0.3446 - val_acc: 0.8682
# Epoch 18/20
# 40/40 [==============================] - 39s 969ms/step - loss: 0.0424 - acc: 0.9890 - val_loss: 0.3658 - val_acc: 0.8987
# Epoch 19/20
# 40/40 [==============================] - 39s 974ms/step - loss: 0.0687 - acc: 0.9763 - val_loss: 0.3282 - val_acc: 0.8643
# Epoch 20/20
# 40/40 [==============================] - 38s 945ms/step - loss: 0.0496 - acc: 0.9843 - val_loss: 0.4273 - val_acc: 0.8326

# %%
# summarize history for accuracy
plt.plot(avghistory.history['acc'])
plt.plot(avghistory.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower left')
plt.ylim(ymin=0)
plt.show()
# summarize history for loss
plt.plot(avghistory.history['loss'])
plt.plot(avghistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymax=1)
plt.show()

# %%
avg1 = Sequential()
#Convolve-Pool
avg1.add(Conv2D(32,(3,3), input_shape = (64,64,3), activation = 'relu'))
avg1.add(AveragePooling2D(pool_size=(2, 2)))

avg1.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
avg1.add(AveragePooling2D(pool_size=(2,2)))
avg1.add(Dropout(0.25))

#Flatten
avg1.add(Flatten())
#Fully-connected
avg1.add(Dense(units=128, activation = 'relu'))
avg1.add(Dense(units=1, activation = 'sigmoid'))

# %%
avg1.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
avg1history = avg1.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 40s 989ms/step - loss: 0.6093 - acc: 0.6668 - val_loss: 0.5039 - val_acc: 0.7885
# Epoch 2/20
# 40/40 [==============================] - 39s 968ms/step - loss: 0.3795 - acc: 0.8401 - val_loss: 0.5058 - val_acc: 0.7868
# Epoch 3/20
# 40/40 [==============================] - 39s 964ms/step - loss: 0.3446 - acc: 0.8603 - val_loss: 0.5116 - val_acc: 0.7841
# Epoch 4/20
# 40/40 [==============================] - 39s 966ms/step - loss: 0.2750 - acc: 0.8998 - val_loss: 0.3797 - val_acc: 0.8295
# Epoch 5/20
# 40/40 [==============================] - 38s 962ms/step - loss: 0.2412 - acc: 0.9092 - val_loss: 0.4525 - val_acc: 0.8370
# Epoch 6/20
# 40/40 [==============================] - 38s 952ms/step - loss: 0.2134 - acc: 0.9127 - val_loss: 0.4461 - val_acc: 0.8217
# Epoch 7/20
# 40/40 [==============================] - 38s 946ms/step - loss: 0.1620 - acc: 0.9382 - val_loss: 0.4047 - val_acc: 0.8458
# Epoch 8/20
# 40/40 [==============================] - 42s 1s/step - loss: 0.1460 - acc: 0.9468 - val_loss: 0.4513 - val_acc: 0.8256
# Epoch 9/20
# 40/40 [==============================] - 40s 994ms/step - loss: 0.1609 - acc: 0.9411 - val_loss: 0.4180 - val_acc: 0.8546
# Epoch 10/20
# 40/40 [==============================] - 40s 998ms/step - loss: 0.1375 - acc: 0.9435 - val_loss: 0.3782 - val_acc: 0.8643
# Epoch 11/20
# 40/40 [==============================] - 38s 954ms/step - loss: 0.1023 - acc: 0.9560 - val_loss: 0.6280 - val_acc: 0.8414
# Epoch 12/20
# 40/40 [==============================] - 39s 963ms/step - loss: 0.0777 - acc: 0.9734 - val_loss: 0.3706 - val_acc: 0.8605
# Epoch 13/20
# 40/40 [==============================] - 38s 951ms/step - loss: 0.0866 - acc: 0.9695 - val_loss: 0.3374 - val_acc: 0.8546
# Epoch 14/20
# 40/40 [==============================] - 39s 980ms/step - loss: 0.0586 - acc: 0.9812 - val_loss: 0.3434 - val_acc: 0.8992
# Epoch 15/20
# 40/40 [==============================] - 37s 936ms/step - loss: 0.0512 - acc: 0.9828 - val_loss: 0.5738 - val_acc: 0.8590
# Epoch 16/20
# 40/40 [==============================] - 38s 961ms/step - loss: 0.0560 - acc: 0.9843 - val_loss: 0.4073 - val_acc: 0.8643
# Epoch 17/20
# 40/40 [==============================] - 40s 993ms/step - loss: 0.0630 - acc: 0.9732 - val_loss: 0.4348 - val_acc: 0.9031
# Epoch 18/20
# 40/40 [==============================] - 39s 977ms/step - loss: 0.0456 - acc: 0.9836 - val_loss: 0.3439 - val_acc: 0.9147
# Epoch 19/20
# 40/40 [==============================] - 38s 945ms/step - loss: 0.1119 - acc: 0.9591 - val_loss: 0.3504 - val_acc: 0.8767
# Epoch 20/20
# 40/40 [==============================] - 40s 993ms/step - loss: 0.0510 - acc: 0.9804 - val_loss: 0.3395 - val_acc: 0.9070

# %%
# summarize history for accuracy
plt.plot(avg1history.history['acc'])
plt.plot(avg1history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower left')
plt.ylim(ymin=0)
plt.show()
# summarize history for loss
plt.plot(avg1history.history['loss'])
plt.plot(avg1history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymax=1)
plt.show()

# %% [markdown]
# ## Min0 Pool

# %%
#def median_output_shape(input_shape):
#    shape = list(input_shape)
#    shape[1] *= 2
#    shape[2] /= 2
#    shape[3] /= 2
#    return tuple(shape)

# %%
#def median_pool2d(x):
#    median = tf.contrib.distributions.percentile(x, 50.0)
#    print(x)
#    return median

# %%
import tensorflow as tf

init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    
def min0_pool2d(x):
   
    min_x = -K.pool2d(-x, pool_size=(2, 2))
    return min_x

def min0_pool2d_output_shape(input_shape):
    shape = list(input_shape)
    shape[1] *= 2
    return tuple(shape)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# ResourceExhaustedError: OOM when allocating tensor of shape [32] and type float
# 	 [[{{node training_9/Adam/zeros_7}}]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-65-e530a8465526> in <module>
#       3 init = tf.global_variables_initializer()
#       4 with tf.Session() as sess:
# ----> 5     sess.run(init)
#       6
#       7 def min0_pool2d(x):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor of shape [32] and type float
# 	 [[node training_9/Adam/zeros_7 (defined at C:\Users\aftermath\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:702) ]]
#
# Caused by op 'training_9/Adam/zeros_7', defined at:
#   File "C:\Users\aftermath\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\aftermath\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\aftermath\Anaconda3\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "C:\Users\aftermath\Anaconda3\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "C:\Users\aftermath\Anaconda3\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\gen.py", line 781, in inner
#     self.run()
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3214, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-60-f47badeaa4de>", line 1, in <module>
#     minzerohistory = minzero.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\legacy\interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\engine\training.py", line 1418, in fit_generator
#     initial_epoch=initial_epoch)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\engine\training_generator.py", line 40, in fit_generator
#     model._make_train_function()
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\engine\training.py", line 509, in _make_train_function
#     loss=self.total_loss)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\legacy\interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\optimizers.py", line 488, in get_updates
#     vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\optimizers.py", line 488, in <listcomp>
#     vs = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py", line 702, in zeros
#     v = tf.zeros(shape=shape, dtype=tf_dtype, name=name)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py", line 1805, in zeros
#     output = _constant_if_small(zero, shape, dtype, name)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py", line 1763, in _constant_if_small
#     return constant(value, shape=shape, dtype=dtype, name=name)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py", line 245, in constant
#     allow_broadcast=True)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py", line 289, in _constant_impl
#     name=name).outputs[0]
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor of shape [32] and type float
# 	 [[node training_9/Adam/zeros_7 (defined at C:\Users\aftermath\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:702) ]]

# %%
minzero = Sequential()

#Convolve-Pool
minzero.add(Conv2D(filters=32,kernel_size=(3,3), input_shape = (64,64,3), activation = 'relu'))
minzero.add(Lambda(min0_pool2d, output_shape=min0_pool2d_output_shape))

#Flatten
minzero.add(Flatten())
#Fully-connected
minzero.add(Dense(units=128, activation = 'relu'))
minzero.add(Dense(units=1, activation = 'sigmoid'))

# %%
minzero.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
minzerohistory = minzero.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-61-f47badeaa4de> in <module>
# ----> 1 minzerohistory = minzero.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# FailedPreconditionError: Attempting to use uninitialized value dense_19/bias
# 	 [[{{node dense_19/bias/read}}]]
# 	 [[{{node metrics_9/acc/Mean_1}}]]

# %% [markdown]
# ## Min Pool

# %%
from keras import backend as K
from keras.layers import Lambda

# %%
def min_pool2d(x):

    max_val = K.max(x) + 1 # we gonna replace all zeros with that value
    # replace all 0s with very high numbers
    is_zero = max_val * K.cast(K.equal(x,0), dtype=K.floatx())
    x = is_zero + x

    # execute pooling with 0s being replaced by a high number
    min_x = -K.pool2d(-x, pool_size=(2, 2), strides=(2, 2))

    # depending on the value we either substract the zero replacement or not
    is_result_zero = max_val * K.cast(K.equal(min_x, max_val), dtype=K.floatx()) 
    min_x = min_x - is_result_zero

    return min_x # concatenate on channel

# %%
min = Sequential()
#Convolve-Pool
min.add(Conv2D(filters=32,kernel_size=(3,3), input_shape = (64,64,3), activation = 'relu'))
min.add(Lambda(min_pool2d))

#Flatten
min.add(Flatten())
#Fully-connected
min.add(Dense(units=128, activation = 'relu'))
min.add(Dense(units=1, activation = 'sigmoid'))

# %%
min.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
minhistory = min.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# WARNING:tensorflow:From C:\Users\aftermath\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.6537 - acc: 0.7531 - val_loss: 0.4687 - val_acc: 0.8023
# Epoch 2/20
# 40/40 [==============================] - 37s 927ms/step - loss: 0.3243 - acc: 0.8715 - val_loss: 0.3405 - val_acc: 0.8502
# Epoch 3/20
# 40/40 [==============================] - 40s 998ms/step - loss: 0.2892 - acc: 0.8801 - val_loss: 0.3725 - val_acc: 0.8488
# Epoch 4/20
# 40/40 [==============================] - 39s 981ms/step - loss: 0.2311 - acc: 0.9129 - val_loss: 0.3334 - val_acc: 0.8855
# Epoch 5/20
# 40/40 [==============================] - 39s 986ms/step - loss: 0.1874 - acc: 0.9239 - val_loss: 0.3353 - val_acc: 0.8760
# Epoch 6/20
# 40/40 [==============================] - 40s 999ms/step - loss: 0.1957 - acc: 0.9206 - val_loss: 0.3893 - val_acc: 0.8458
# Epoch 7/20
# 40/40 [==============================] - 38s 957ms/step - loss: 0.1622 - acc: 0.9346 - val_loss: 0.2768 - val_acc: 0.8876
# Epoch 8/20
# 40/40 [==============================] - 39s 972ms/step - loss: 0.1744 - acc: 0.9380 - val_loss: 0.3863 - val_acc: 0.8590
# Epoch 9/20
# 40/40 [==============================] - 39s 975ms/step - loss: 0.1513 - acc: 0.9437 - val_loss: 0.3157 - val_acc: 0.8915
# Epoch 10/20
# 40/40 [==============================] - 40s 992ms/step - loss: 0.0998 - acc: 0.9710 - val_loss: 0.3791 - val_acc: 0.8722
# Epoch 11/20
# 40/40 [==============================] - 39s 982ms/step - loss: 0.1402 - acc: 0.9487 - val_loss: 0.3778 - val_acc: 0.8643
# Epoch 12/20
# 40/40 [==============================] - 39s 980ms/step - loss: 0.1596 - acc: 0.9423 - val_loss: 0.3057 - val_acc: 0.8855
# Epoch 13/20
# 40/40 [==============================] - 38s 956ms/step - loss: 0.1204 - acc: 0.9507 - val_loss: 0.4311 - val_acc: 0.8527
# Epoch 14/20
# 40/40 [==============================] - 41s 1s/step - loss: 0.0791 - acc: 0.9757 - val_loss: 0.3634 - val_acc: 0.8767
# Epoch 15/20
# 40/40 [==============================] - 40s 992ms/step - loss: 0.0889 - acc: 0.9687 - val_loss: 0.4009 - val_acc: 0.8953
# Epoch 16/20
# 40/40 [==============================] - 39s 983ms/step - loss: 0.0833 - acc: 0.9716 - val_loss: 0.3460 - val_acc: 0.8899
# Epoch 17/20
# 40/40 [==============================] - 39s 987ms/step - loss: 0.0858 - acc: 0.9638 - val_loss: 0.4908 - val_acc: 0.8876
# Epoch 18/20
# 40/40 [==============================] - 40s 996ms/step - loss: 0.0875 - acc: 0.9654 - val_loss: 0.3761 - val_acc: 0.8678
# Epoch 19/20
# 40/40 [==============================] - 39s 972ms/step - loss: 0.0569 - acc: 0.9859 - val_loss: 0.4313 - val_acc: 0.8721
# Epoch 20/20
# 40/40 [==============================] - 39s 985ms/step - loss: 0.0495 - acc: 0.9859 - val_loss: 0.5615 - val_acc: 0.8238

# %%
# summarize history for accuracy
plt.plot(minhistory.history['acc'])
plt.plot(minhistory.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymin=0)
plt.show()
# summarize history for loss
plt.plot(minhistory.history['loss'])
plt.plot(minhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymax=1)
plt.show()

# %%
min1 = Sequential()
#Convolve-Pool
min1.add(Conv2D(filters=32,kernel_size=(3,3), input_shape = (64,64,3), activation = 'relu'))
min1.add(Lambda(min_pool2d))

min1.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same'))
min1.add(Lambda(min_pool2d))
min1.add(Dropout(0.25))


#Flatten
min1.add(Flatten())
#Fully-connected
min1.add(Dense(units=128, activation = 'relu'))
min1.add(Dense(units=1, activation = 'sigmoid'))

# %%
min1.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
min1history = min1.fit_generator(training_set,  epochs = 20, validation_data = testing_set, steps_per_epoch=40,validation_steps=10)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.5274 - acc: 0.7535 - val_loss: 0.4019 - val_acc: 0.7930
# Epoch 2/20
# 40/40 [==============================] - 39s 976ms/step - loss: 0.3924 - acc: 0.8542 - val_loss: 0.3736 - val_acc: 0.8256
# Epoch 3/20
# 40/40 [==============================] - 38s 962ms/step - loss: 0.3272 - acc: 0.8791 - val_loss: 0.3700 - val_acc: 0.8634
# Epoch 4/20
# 40/40 [==============================] - 39s 976ms/step - loss: 0.3110 - acc: 0.8803 - val_loss: 0.3263 - val_acc: 0.8566
# Epoch 5/20
# 40/40 [==============================] - 43s 1s/step - loss: 0.2932 - acc: 0.8887 - val_loss: 0.2264 - val_acc: 0.9119
# Epoch 6/20
# 40/40 [==============================] - 38s 946ms/step - loss: 0.2407 - acc: 0.9008 - val_loss: 0.2738 - val_acc: 0.9070
# Epoch 7/20
# 40/40 [==============================] - 40s 994ms/step - loss: 0.2070 - acc: 0.9229 - val_loss: 0.2694 - val_acc: 0.9251
# Epoch 8/20
# 40/40 [==============================] - 40s 990ms/step - loss: 0.2690 - acc: 0.8914 - val_loss: 0.3169 - val_acc: 0.8605
# Epoch 9/20
# 40/40 [==============================] - 39s 985ms/step - loss: 0.2116 - acc: 0.9217 - val_loss: 0.3336 - val_acc: 0.8811
# Epoch 10/20
# 40/40 [==============================] - 39s 974ms/step - loss: 0.1591 - acc: 0.9286 - val_loss: 0.3373 - val_acc: 0.9070
# Epoch 11/20
# 40/40 [==============================] - 40s 994ms/step - loss: 0.1573 - acc: 0.9395 - val_loss: 0.3464 - val_acc: 0.8899
# Epoch 12/20
# 40/40 [==============================] - 39s 978ms/step - loss: 0.1422 - acc: 0.9440 - val_loss: 0.3580 - val_acc: 0.8798
# Epoch 13/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.1519 - acc: 0.9419 - val_loss: 0.2658 - val_acc: 0.9119
# Epoch 14/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.1124 - acc: 0.9585 - val_loss: 0.4025 - val_acc: 0.8488
# Epoch 15/20
# 40/40 [==============================] - 39s 974ms/step - loss: 0.1239 - acc: 0.9495 - val_loss: 0.3881 - val_acc: 0.8899
# Epoch 16/20
# 40/40 [==============================] - 41s 1s/step - loss: 0.1343 - acc: 0.9413 - val_loss: 0.4702 - val_acc: 0.8721
# Epoch 17/20
# 40/40 [==============================] - 39s 984ms/step - loss: 0.1323 - acc: 0.9450 - val_loss: 0.2662 - val_acc: 0.9251
# Epoch 18/20
# 40/40 [==============================] - 40s 1s/step - loss: 0.0893 - acc: 0.9664 - val_loss: 0.3912 - val_acc: 0.8876
# Epoch 19/20
# 40/40 [==============================] - 38s 959ms/step - loss: 0.0659 - acc: 0.9789 - val_loss: 0.3459 - val_acc: 0.9119
# Epoch 20/20
# 40/40 [==============================] - 42s 1s/step - loss: 0.0744 - acc: 0.9708 - val_loss: 0.3822 - val_acc: 0.8760

# %%
# summarize history for accuracy
plt.plot(min1history.history['acc'])
plt.plot(min1history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower left')
plt.ylim(ymin=0)
plt.show()
# summarize history for loss
plt.plot(min1history.history['loss'])
plt.plot(min1history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.ylim(ymax=1)
plt.show()
# Out:
# C:\Users\aftermath\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
